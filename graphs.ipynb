# %%
import os
from mpl_toolkits.mplot3d.axes3d import Axes3D
from colorline import colorline
import pycoasters.images
reload(pycoasters.images)
from pycoasters.images import show
import pycoasters.coaster
reload(pycoasters.coaster)
import PIL.Image as Im
from pycoasters.coaster import Coaster, a2color

# %%
ride_name = 'gemini'
data_folder = 'data/2013-09-28-cedar-point'
ride_folder = os.path.join(data_folder, ride_name)

# %%
c = Coaster.load(ride_folder)

# %%
base_path = data_folder

# %%
folders = []
def visit(arg, dirname, names):
    if 'accelerometer_log.txt' in names:
        folders.append(dirname)
os.path.walk(base_path, visit, None)
print folders
# Out:
# ['data/2013-09-28-cedar-point/at_rest', 'data/2013-09-28-cedar-point/cedar_creek_mine_ride', 'data/2013-09-28-cedar-point/gatekeeper', 'data/2013-09-28-cedar-point/gemini', 'data/2013-09-28-cedar-point/giant_wheel', 'data/2013-09-28-cedar-point/iron_dragon', 'data/2013-09-28-cedar-point/magnum_xl200', 'data/2013-09-28-cedar-point/max_air', 'data/2013-09-28-cedar-point/wind_seeker', 'data/2013-09-28-cedar-point/witches_wheel']

# %% [raw]
# fig = figure(figsize=(11,11))
# ax = fig.add_subplot(111, projection='3d')
# c.plot_xtz_3d(ax)
# ax.view_init(15,330)
# draw()
# savefig(os.path.join(ride_folder, 'accel_3d.pdf'))
# savefig(os.path.join(ride_folder, 'accel_3d.svg'))
#
# # colorline(c.x, c.t, c.z, c=c.t, linestyle='-', linewidth=0.5)
# # rs = [min(z), max(z)]
# # r = rs[1] - rs[0]
# # ax.auto_scale_xyz([-r/2, r/2], [-r/2,r/2], rs)

# %%
f, axs = subplots(3,1,figsize=(8,16))
c.plot_magnitude(axs[0])
c.plot_original_xyz(axs[1])
c.plot_reoriented_xyz(axs[2])
draw()
# savefig(os.path.join(ride_folder, 'acceleration.svg'))
# savefig(os.path.join(ride_folder, 'acceleration.pdf'))
# savefig(os.path.join(ride_folder, 'acceleration.png'))

# %%
img = c.portrait_square()
mag = 10
img = dstack([kron(img[:,:,j], ones((mag,mag))) for j in range(img.shape[2])])
show(img)

img = c.portrait_line()
show(img)
gca().get_xaxis().set_visible(False)
gca().get_yaxis().set_visible(False)

# %%
sqrt(sum([power(v, 2) for v in (c.x,c.y,c.z)]))
# Out:
# 53.119571722671083

# %%
m = sqrt(sum(vstack([power(v, 2) for v in (c.x,c.y,c.z)]),axis=0))
print m.shape
# Out:
# (2541,)

# %%
print m
# Out:
# [ 0.90824006  0.90824006  0.90824006 ...,  0.94519839  0.93626919
#   0.89140339]

# %% [raw]
# tup = (c.x, c.z, c.y)  # order chosen for aesthetics
# img = a2color(*tup)
# figure(figsize=(25,25))
# ax = axes([0.1, 0.1, 0.8, 0.8])
# p = ax.pie([1]*img.shape[0],colors=img[:,[0,2,1]]/255.0)
# for pw in p[0]:
#     pw.set_lw(0)
# draw()
# savefig(os.path.join(ride_folder, 'accel_pie.pdf'))

# %%
mag = np.sqrt(np.power(c.x, 2) + np.power(c.y, 2) + np.power(c.z, 2))
s = 8
tup = (c.x * s/mag, c.z * s/mag, c.y * s/mag)  # order chosen for aesthetics
img = a2color(*tup)
figure(figsize=(25,25))
ax = subplot(111,polar=True)
ax.set_theta_direction(-1)
ax.set_theta_offset(np.pi/2)

ndx = range(0,img.shape[0],50)
img = img[ndx,:]
mag = mag[ndx]
# ax.plot([0,0], [log(mag[0]+1), log(5)], '--', color=[0.5,0.5,0.5,0.5], linewidth=5)
p = ax.bar(linspace(0,2*pi,img.shape[0]),
           log(mag+1),
           width=2*pi/img.shape[0],
           color=img[:,[0,2,1]]/255.0,
           linewidth=0)
# ax.set_ylim([0,4])
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# ax.annotate("",xy=(np.pi/16, log(3)), xycoords="data", 
#             xytext=(0, log(3)),
#             size=40,
#             arrowprops={'arrowstyle': 'simple',
#                         'color':'0.8',
#                         'connectionstyle': 'arc3,rad=-0.2'})
ax.set_ylim([0, log(5)])
rc('text', usetex=True)
rc('font', family='sans-serif')
ax.set_title(c.notes['title'],
             fontdict={'family':'serif',
                       'size':58})
draw()
savefig(os.path.join(ride_folder, 'accel_polar.png'))
